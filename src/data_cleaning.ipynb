# %%
import pandas as pd

# %%
df = pd.read_csv('..\data\FAA Wildlife Strikes.csv')

# %%
df.iloc[ : , :7]
# Out:
#       Airport: Code                Airport: Name  Origin State  \
# 0              KAAF   APALACHICOLA REGIONAL ARPT       Florida
# 1              KAAF   APALACHICOLA REGIONAL ARPT       Florida
# 2              KABE           LEHIGH VALLEY INTL  Pennsylvania
# 3              KABE           LEHIGH VALLEY INTL  Pennsylvania
# 4              KABE           LEHIGH VALLEY INTL  Pennsylvania
# ...             ...                          ...           ...
# 28293          KYNG  YOUNGSTOWN-WARREN RGNL ARPT          Ohio
# 28294          KYNG  YOUNGSTOWN-WARREN RGNL ARPT          Ohio
# 28295          KYNG  YOUNGSTOWN-WARREN RGNL ARPT          Ohio
# 28296          KYNG  YOUNGSTOWN-WARREN RGNL ARPT          Ohio
# 28297          KZPH   ZEPHYRHILLS MUNICIPAL ARPT       Florida
#
#       Origin State Code        Country Aircraft: Type  \
# 0                    FL  United States            NaN
# 1                    FL  United States       Airplane
# 2                    PA  United States       Airplane
# 3                    PA  United States       Airplane
# 4                    PA  United States       Airplane
# ...                 ...            ...            ...
# 28293                OH  United States       Airplane
# 28294                OH  United States       Airplane
# 28295                OH  United States       Airplane
# 28296                OH  United States       Airplane
# 28297                FL  United States       Airplane
#
#        Aircraft: Number of engines
# 0                              NaN
# 1                              1.0
# 2                              2.0
# 3                              2.0
# 4                              2.0
# ...                            ...
# 28293                          4.0
# 28294                          4.0
# 28295                          4.0
# 28296                          4.0
# 28297                          3.0
#
# [28298 rows x 7 columns]

# %%
df['Aircraft: Number of engines'] = pd.to_numeric(df['Aircraft: Number of engines'], errors='coerce').astype(pd.Int64Dtype())

# %%
df.iloc[ : , 6:13]
# Out:
#        Aircraft: Number of engines Collision Date and Time When: Time of day  \
# 0                             <NA>           9/20/12 19:30               NaN
# 1                                1           4/23/13 17:09               NaN
# 2                                2            4/23/09 9:22               Day
# 3                                2           4/13/14 22:00             Night
# 4                                2           3/31/09 18:15               Day
# ...                            ...                     ...               ...
# 28293                            4          11/16/11 18:20               NaN
# 28294                            4           11/1/12 21:20               NaN
# 28295                            4            5/7/14 22:00               NaN
# 28296                            4          10/28/13 18:30               NaN
# 28297                            3           11/5/00 14:00               Day
#
#       When: Phase of flight Effect: Amount of damage (detailed)  \
# 0              Take-off run                                None
# 1              Take-off run                                None
# 2              Take-off run                              Medium
# 3                  Approach                                None
# 4                  Approach                              Medium
# ...                     ...                                 ...
# 28293              Approach                                None
# 28294              Approach                                None
# 28295          Take-off run                                None
# 28296              Approach                                None
# 28297               Descent                               Minor
#
#       Effect: Impact to flight Effect: Indicated Damage
# 0                         None                No damage
# 1                         None                No damage
# 2             Aborted Take-off            Caused damage
# 3                         None                No damage
# 4                         None            Caused damage
# ...                        ...                      ...
# 28293                     None                No damage
# 28294                     None                No damage
# 28295                     None                No damage
# 28296                     None                No damage
# 28297                     None            Caused damage
#
# [28298 rows x 7 columns]

# %%
df['Collision Date and Time'] = pd.to_datetime(df['Collision Date and Time'])

# %%
df['Collision Date and Time'] = pd.to_datetime(df['Collision Date and Time'])
df['Day of Year'] = df['Collision Date and Time'].dt.dayofyear

# %%
df.iloc[ : , 12:19]
# Out:
#       Effect: Indicated Damage Cost: Aircraft time out of service (hours)  \
# 0                    No damage                                        NaN
# 1                    No damage                                        NaN
# 2                Caused damage                                        720
# 3                    No damage                                         15
# 4                Caused damage                                         12
# ...                        ...                                        ...
# 28293                No damage                                        NaN
# 28294                No damage                                        NaN
# 28295                No damage                                        NaN
# 28296                No damage                                        NaN
# 28297            Caused damage                                        NaN
#
#       Cost: Total $    Days Feet above ground  Miles from airport  \
# 0                 0     NaN                 0                 NaN
# 1                 0     NaN               NaN                 NaN
# 2           171,132  30.000                 0                 0.0
# 3               600   0.625               NaN                 NaN
# 4           188,245   0.500               NaN                 0.0
# ...             ...     ...               ...                 ...
# 28293             0     NaN               100                 NaN
# 28294             0     NaN             1,900                 NaN
# 28295             0     NaN               NaN                 NaN
# 28296             0     NaN               NaN                 NaN
# 28297             0     NaN             4,000                 NaN
#
#       Wildlife: Animal Category
# 0           Terrestrial Mammals
# 1                         Birds
# 2                         Birds
# 3                         Birds
# 4                         Birds
# ...                         ...
# 28293                     Birds
# 28294                     Birds
# 28295                     Birds
# 28296                     Birds
# 28297                     Birds
#
# [28298 rows x 7 columns]

# %%
feet_to_meters = 0.3048
df['m above ground'] = df['Feet above ground'] * feet_to_meters

# %%
miles_to_km = 1.60934
df['km from airport'] = df['Miles from airport'] * miles_to_km

# %%
df['Cost: Total $'] = df['Cost: Total $'].str.replace(',', '')

# %%
df['Cost: Total $'] = df['Cost: Total $'].astype(int)

# %%
df['Cost: Total $'] = pd.to_numeric(df['Cost: Total $'], errors='coerce').astype(pd.Int64Dtype())

# %%
df['Feet above ground'] = df['Feet above ground'].str.replace(',', '')
df['Feet above ground'] = pd.to_numeric(df['Feet above ground'], errors='coerce')

# %%
df.iloc[ : , 18:]
# Out:
#       Wildlife: Animal Category                     Wildlife: Species Order  \
# 0           Terrestrial Mammals                                      Canids
# 1                         Birds  Pelicans, Herons, Egrets, Bitterns, Ibises
# 2                         Birds                          Caracaras, Falcons
# 3                         Birds                           Pigeons and Doves
# 4                         Birds     Hawks, Kites, Eagles, Ospreys, Vultures
# ...                         ...                                         ...
# 28293                     Birds                              Perching Birds
# 28294                     Birds              Ducks, Geese, Swans, Waterfowl
# 28295                     Birds                              Perching Birds
# 28296                     Birds                              Perching Birds
# 28297                     Birds     Hawks, Kites, Eagles, Ospreys, Vultures
#
#            Wildlife: Species Group         Wildlife: Species  \
# 0      Wolves, Dogs, Foxes, Coyote              Domestic dog
# 1         Herons, Egrets, Bitterns  Herons, egrets, bitterns
# 2               Caracaras, Falcons          American kestrel
# 3                            Doves             Mourning dove
# 4             Kites, Hawks, Eagles           Red-tailed hawk
# ...                            ...                       ...
# 28293                   Blackbirds           Rusty blackbird
# 28294                        Ducks                Ruddy duck
# 28295                     Sparrows     White-crowned sparrow
# 28296                     Waxwings             Cedar waxwing
# 28297                     Vultures        New World Vultures
#
#       Wildlife: Species ID  Number of Strikes  Record ID  Day of Year  \
# 0                     1F12                  1      17459          264
# 1                       I1                  1      17114          113
# 2                    K5114                  1     259361          113
# 3                    O2205                  1     345167          103
# 4                    K3302                  1     262782           90
# ...                    ...                ...        ...          ...
# 28293                ZT106                  1      15818          320
# 28294                J2140                  1      16759          306
# 28295                ZX309                  1      17575          127
# 28296                ZD102                  1      17262          301
# 28297                   K1                  1     203484          310
#
#        m above ground  km from airport
# 0                0.00              NaN
# 1                 NaN              NaN
# 2                0.00              0.0
# 3                 NaN              NaN
# 4                 NaN              0.0
# ...               ...              ...
# 28293           30.48              NaN
# 28294          579.12              NaN
# 28295             NaN              NaN
# 28296             NaN              NaN
# 28297         1219.20              NaN
#
# [28298 rows x 10 columns]

# %%
null_records = df[df['Record ID'].isnull()]
non_unique_records = df[df.duplicated(subset=['Record ID'], keep=False)]

print("NULL Records:")
print(null_records)

print("\nNon-Unique Records:")
print(non_unique_records)
# Out:
# NULL Records:
# Empty DataFrame
# Columns: [Airport: Code, Airport: Name, Origin State, Origin State Code, Country, Aircraft: Type, Aircraft: Number of engines, Collision Date and Time, When: Time of day, When: Phase of flight, Effect: Amount of damage (detailed), Effect: Impact to flight, Effect: Indicated Damage, Cost: Aircraft time out of service (hours), Cost: Total $, Days, Feet above ground, Miles from airport, Wildlife: Animal Category, Wildlife: Species Order, Wildlife: Species Group, Wildlife: Species, Wildlife: Species ID, Number of Strikes, Record ID, Day of Year, m above ground, km from airport]
# Index: []
#
# [0 rows x 28 columns]
#
# Non-Unique Records:
# Empty DataFrame
# Columns: [Airport: Code, Airport: Name, Origin State, Origin State Code, Country, Aircraft: Type, Aircraft: Number of engines, Collision Date and Time, When: Time of day, When: Phase of flight, Effect: Amount of damage (detailed), Effect: Impact to flight, Effect: Indicated Damage, Cost: Aircraft time out of service (hours), Cost: Total $, Days, Feet above ground, Miles from airport, Wildlife: Animal Category, Wildlife: Species Order, Wildlife: Species Group, Wildlife: Species, Wildlife: Species ID, Number of Strikes, Record ID, Day of Year, m above ground, km from airport]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.set_index('Record ID', inplace=True)  
df.to_csv('../data/FAA_wildlife_strikes_cleaned.csv', index=True)
